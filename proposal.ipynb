# %% [markdown]
# <h1 style="text-align: center;">STAT 447C: Final Project Proposal</h1>
# <h2 style="text-align: center;">Andrew Tran (80921547)</h2>
#
# ## Theme
#
# The theme of this project will be one of the following topics:
#
# 1. Careful and scientific comparison between Bayesian and frequentist regression/classification techniques
# 2. Deep generative models
# 3. Variational inference
#
# ## GitHub
#
# https://github.com/nartyuh/ubc-stat-447C-project
#
# ## Data
#
# Two potential datasets for this project:
# 1. Breast Cancer Wisconsin (Diagnostic)
# 2. House Prices - Advanced Regression Techniques
#
# ### Breast Cancer Wisconsin (Diagnostic)
#
# Source: https://archive.ics.uci.edu/dataset/17/breast+cancer+wisconsin+diagnostic

# %%
# fetch dataset 
from ucimlrepo import fetch_ucirepo 
breast_cancer_wisconsin_diagnostic = fetch_ucirepo(id=17)

# %% [markdown]
# #### Variables
#
# Not counting `ID`, we have 31 variables. `Diagnosis` is our response variable. The other 30 variables are our explanatory variables.

# %%
print(breast_cancer_wisconsin_diagnostic.variables["name"].values)
# Out:
# ['ID' 'Diagnosis' 'radius1' 'texture1' 'perimeter1' 'area1' 'smoothness1'
#  'compactness1' 'concavity1' 'concave_points1' 'symmetry1'
#  'fractal_dimension1' 'radius2' 'texture2' 'perimeter2' 'area2'
#  'smoothness2' 'compactness2' 'concavity2' 'concave_points2' 'symmetry2'
#  'fractal_dimension2' 'radius3' 'texture3' 'perimeter3' 'area3'
#  'smoothness3' 'compactness3' 'concavity3' 'concave_points3' 'symmetry3'
#  'fractal_dimension3']

# %% [markdown]
# #### Data
#
# Our dataset has 569 observations.

# %%
import pandas as pd

x = breast_cancer_wisconsin_diagnostic.data.features 
y = breast_cancer_wisconsin_diagnostic.data.targets 

display(pd.concat([y, x], axis=1))
# Out:
#     Diagnosis  radius1  texture1  perimeter1   area1  smoothness1  \
# 0           M    17.99     10.38      122.80  1001.0      0.11840
# 1           M    20.57     17.77      132.90  1326.0      0.08474
# 2           M    19.69     21.25      130.00  1203.0      0.10960
# 3           M    11.42     20.38       77.58   386.1      0.14250
# 4           M    20.29     14.34      135.10  1297.0      0.10030
# ..        ...      ...       ...         ...     ...          ...
# 564         M    21.56     22.39      142.00  1479.0      0.11100
# 565         M    20.13     28.25      131.20  1261.0      0.09780
# 566         M    16.60     28.08      108.30   858.1      0.08455
# 567         M    20.60     29.33      140.10  1265.0      0.11780
# 568         B     7.76     24.54       47.92   181.0      0.05263
#
#      compactness1  concavity1  concave_points1  symmetry1  ...  radius3  \
# 0         0.27760     0.30010          0.14710     0.2419  ...   25.380
# ...

# %% [markdown]
# ### House Prices - Advanced Regression Techniques
#
# Source: https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques

# %%
house_prices = pd.read_csv('data/house_prices/train.csv')

# %% [markdown]
# #### Variables
#
# Not counting `ID`, we have 80 variables. `SalePrice` is our response variable. The other 79 variables are our explanatory variables.

# %%
print(house_prices.columns.values)
# Out:
# ['Id' 'MSSubClass' 'MSZoning' 'LotFrontage' 'LotArea' 'Street' 'Alley'
#  'LotShape' 'LandContour' 'Utilities' 'LotConfig' 'LandSlope'
#  'Neighborhood' 'Condition1' 'Condition2' 'BldgType' 'HouseStyle'
#  'OverallQual' 'OverallCond' 'YearBuilt' 'YearRemodAdd' 'RoofStyle'
#  'RoofMatl' 'Exterior1st' 'Exterior2nd' 'MasVnrType' 'MasVnrArea'
#  'ExterQual' 'ExterCond' 'Foundation' 'BsmtQual' 'BsmtCond' 'BsmtExposure'
#  'BsmtFinType1' 'BsmtFinSF1' 'BsmtFinType2' 'BsmtFinSF2' 'BsmtUnfSF'
#  'TotalBsmtSF' 'Heating' 'HeatingQC' 'CentralAir' 'Electrical' '1stFlrSF'
#  '2ndFlrSF' 'LowQualFinSF' 'GrLivArea' 'BsmtFullBath' 'BsmtHalfBath'
#  'FullBath' 'HalfBath' 'BedroomAbvGr' 'KitchenAbvGr' 'KitchenQual'
#  'TotRmsAbvGrd' 'Functional' 'Fireplaces' 'FireplaceQu' 'GarageType'
#  'GarageYrBlt' 'GarageFinish' 'GarageCars' 'GarageArea' 'GarageQual'
#  'GarageCond' 'PavedDrive' 'WoodDeckSF' 'OpenPorchSF' 'EnclosedPorch'
#  '3SsnPorch' 'ScreenPorch' 'PoolArea' 'PoolQC' 'Fence' 'MiscFeature'
# ...

# %% [markdown]
# #### Data
#
# Our dataset has 1460 observations.

# %%
display(house_prices)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...
